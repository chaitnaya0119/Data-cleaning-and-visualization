# %%
import pandas as pd
df = pd.read_csv("F:\\Pandas\\nba.csv")

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.shape
# Out:
# (458, 9)

# %%
df.sort_values(by=['Name','Weight','Salary'],axis=0,ascending=True,inplace=False,kind='quicksort',na_position='last')
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
print(df.groupby('Team',sort=True).sum())
# Out:
#                         Number    Age  Weight       Salary
# Team
# Atlanta Hawks            285.0  423.0  3319.0   72902950.0
# Boston Celtics           478.0  371.0  3292.0   58541068.0
# Brooklyn Nets            274.0  384.0  3234.0   52528475.0
# Charlotte Hornets        257.0  392.0  3306.0   78340920.0
# Chicago Bulls            288.0  411.0  3284.0   86783378.0
# Cleveland Cavaliers      217.0  443.0  3418.0  106988689.0
# Dallas Mavericks         300.0  446.0  3405.0   71198732.0
# Denver Nuggets           229.0  386.0  3263.0   60121930.0
# Detroit Pistons          259.0  393.0  3333.0   67168263.0
# Golden State Warriors    313.0  415.0  3369.0   88868997.0
# Houston Rockets          220.0  403.0  3305.0   75283021.0
# Indiana Pacers           284.0  396.0  3334.0   66751826.0
# Los Angeles Clippers     293.0  442.0  3296.0   94854640.0
# Los Angeles Lakers       241.0  413.0  3406.0   71770431.0
# Memphis Grizzlies        280.0  511.0  3924.0   76550880.0
# ...

# %%
grp = df.groupby('Team').groups

# %%
grp.__getitem__('Atlanta Hawks')
# Out:
# Int64Index([309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321,
#             322, 323],
#            dtype='int64')

# %%
import numpy as np
grp2 = df.groupby(by=('Team'))['Weight','Age'].agg(['sum','mean','std'])
# Out:
# C:\Users\chaitanya\AppData\Local\Temp\ipykernel_16112\1301954613.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp2 = df.groupby(by=('Team'))['Weight','Age'].agg(['sum','mean','std'])

# %%
grp2
# Out:
#                         Weight                           Age             \
#                            sum        mean        std    sum       mean
# Team
# Atlanta Hawks           3319.0  221.266667  25.982045  423.0  28.200000
# Boston Celtics          3292.0  219.466667  25.606547  371.0  24.733333
# Brooklyn Nets           3234.0  215.600000  24.377390  384.0  25.600000
# Charlotte Hornets       3306.0  220.400000  29.908909  392.0  26.133333
# Chicago Bulls           3284.0  218.933333  29.336634  411.0  27.400000
# Cleveland Cavaliers     3418.0  227.866667  27.655706  443.0  29.533333
# Dallas Mavericks        3405.0  227.000000  27.836256  446.0  29.733333
# Denver Nuggets          3263.0  217.533333  26.297384  386.0  25.733333
# Detroit Pistons         3333.0  222.200000  28.899333  393.0  26.200000
# Golden State Warriors   3369.0  224.600000  29.642633  415.0  27.666667
# Houston Rockets         3305.0  220.333333  24.578349  403.0  26.866667
# ...

# %%
grp2 = df.groupby(by=('Team'))
sc = lambda x:(x-x.mean()/x.std())
grp2['Age'].transform(sc)
# Out:
# 0      16.291656
# 1      16.291656
# 2      18.291656
# 3      13.291656
# 4      20.291656
#          ...
# 453    15.995633
# 454    13.995633
# 455    15.995633
# 456    15.995633
# 457          NaN
# Name: Age, Length: 458, dtype: float64

# %%
import pandas as pd

# Create sample DataFrames
data1 = {'A': [1, 2, 3], 'B': [4, 5, 6]}
data2 = {'A': [7, 8, 9], 'B': [10, 11, 12]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Vertical concatenation
result_vertical = pd.concat([df1, df2], axis=0)

print(result_vertical)
# Out:
#    A   B
# 0  1   4
# 1  2   5
# 2  3   6
# 0  7  10
# 1  8  11
# 2  9  12

# %%
import pandas as pd

# Create sample DataFrames
data1 = {'A': [1, 2, 3], 'B': [4, 5, 6]}
data2 = {'C': [7, 8, 9], 'D': [10, 11, 12]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Horizontal concatenation
result_horizontal = pd.concat([df1, df2], axis=1)

print(result_horizontal.reset_index(drop=True))
# Out:
#    A  B  C   D
# 0  1  4  7  10
# 1  2  5  8  11
# 2  3  6  9  12

# %%
df['Team'] = df['Team'].str.cat(df['Name'],sep=',',na_rep=' ')
df['Team']
# Out:
# 0      Boston Celtics,Avery Bradley
# 1        Boston Celtics,Jae Crowder
# 2       Boston Celtics,John Holland
# 3        Boston Celtics,R.J. Hunter
# 4      Boston Celtics,Jonas Jerebko
#                    ...
# 453          Utah Jazz,Shelvin Mack
# 454             Utah Jazz,Raul Neto
# 455          Utah Jazz,Tibor Pleiss
# 456           Utah Jazz,Jeff Withey
# 457                              ,
# Name: Team, Length: 458, dtype: object

# %%
df['Team'].str.split(',')
# Out:
# 0      [Boston Celtics, Avery Bradley]
# 1        [Boston Celtics, Jae Crowder]
# 2       [Boston Celtics, John Holland]
# 3        [Boston Celtics, R.J. Hunter]
# 4      [Boston Celtics, Jonas Jerebko]
#                     ...
# 453          [Utah Jazz, Shelvin Mack]
# 454             [Utah Jazz, Raul Neto]
# 455          [Utah Jazz, Tibor Pleiss]
# 456           [Utah Jazz, Jeff Withey]
# 457                             [ ,  ]
# Name: Team, Length: 458, dtype: object

# %%
import datetime
x = pd.datetime.now()
# Out:
# C:\Users\chaitanya\AppData\Local\Temp\ipykernel_16112\3875145030.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   x = pd.datetime.now()

# %%
x.month,x.year
# Out:
# (8, 2023)

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2023-08-25 11:36:18.036819')

# %%
df.to_csv('ncb data',sep = ',',header=True)
