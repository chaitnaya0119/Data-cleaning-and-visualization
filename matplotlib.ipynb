# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
x=[10,2,5,7,9,8]
y=[9,8,3,4,6,7,]

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.hist(y)
# Out:
# (array([1., 1., 0., 0., 0., 1., 1., 0., 1., 1.]),
#  array([3. , 3.6, 4.2, 4.8, 5.4, 6. , 6.6, 7.2, 7.8, 8.4, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x,y)

# %%
plt.title("This is a scatter plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.scatter(x,y)
plt.show()

# %%
year = [1972, 1982, 1992, 2002, 2012]
e_india = [100.6, 158.61, 305.54, 394.96, 724.79]
e_bangladesh = [10.5, 25.21, 58.65, 119.27, 274.87]

plt.plot(year,e_india,color='orange',marker='.',markersize=10,label='India')
plt.plot(year,e_bangladesh,color='g',linestyle='dashed',linewidth=5,label='Bangladesh')
plt.title('The electricity usuage of india and bangladesh on different year')
plt.xlabel("Year")
plt.ylabel("Amount of electricity")

plt.legend()
plt.show()

# %%
plt.axes([0.1,0.1,1,1])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np


X = np.linspace(-np.pi, np.pi, 15)
C = np.cos(X)
S = np.sin(X)

# [left, bottom, width, height]
ax = plt.axes([0.1, 0.1, 0.8, 0.8])

# 'bs:' mentions blue color, square
# marker with dotted line.
ax1 = ax.plot(X, C, 'bs:')

#'ro-' mentions red color, circle
# marker with solid line.
ax2 = ax.plot(X, S, 'ro-')

ax.legend(labels = ('Cosine Function',
					'Sine Function'),
		loc = 'upper left')

ax.set_title("Trigonometric Functions")

plt.show()
